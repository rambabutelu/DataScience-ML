# %%
#importing th enecessary libraries
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import fix_yahoo_finance as yf
yf.pdr_override() 
import datetime
# %matplotlib inline

# %%
'''
We need to get data using pandas datareader. We will get stock information for the following banks:

Bank of America
CitiGroup
Goldman Sachs
JPMorgan Chase
Morgan Stanley
Wells Fargo
'''

#setting the start and end date
start = datetime.datetime(2009, 1, 1)
end = datetime.datetime(2019, 1, 1)

# %%
#Getting the data using pandas-datareader for different banks

#For Bank of America
BAC = data.get_data_yahoo("BAC", start, end)

#For CitiGroup
CG = data.get_data_yahoo("C", start, end)

#For Goldman Sachs
GS = data.get_data_yahoo("GS", start, end)

#For JPMorgan Chase
JPM = data.get_data_yahoo("JPM", start, end)

#For Morgan Stanley
MS = data.get_data_yahoo("MS", start, end)

#For Wells Fargo
WFC = data.get_data_yahoo("WFC", start, end)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded

# %%
#creating a list of ticker symbols
tickers = ['BAC', 'CG', 'GS', 'JPM', 'MS', 'WFC']

# %%
#concatenating along columns with tickers as keys
bank_stocks = pd.concat([BAC, CG, GS, JPM, MS, WFC], axis=1, keys=tickers)

# %%
#checking the head of the new concatenated DF
bank_stocks.head()
# Out:
#               BAC                                                    CG  \
#              Open   High    Low  Close  Adj Close     Volume       Open
# Date
# 2008-12-31  13.09  14.12  13.00  14.08  12.812518  113351000  67.199997
# 2009-01-02  13.92  14.57  13.71  14.33  13.040014   86580700  68.699997
# 2009-01-05  14.38  14.55  13.89  13.98  12.721521   93640500  71.199997
# 2009-01-06  14.27  14.81  14.07  14.28  12.994514  111015400  72.900002
# 2009-01-07  14.11  14.13  13.61  13.71  12.475824  112810000  72.199997
#
#                                                ...            MS             \
#                  High        Low      Close    ...           Low      Close
# Date                                           ...
# 2008-12-31  70.400002  66.199997  67.099998    ...     15.030000  16.040001
# 2009-01-02  71.599998  67.500000  71.400002    ...     15.750000  16.990000
# 2009-01-05  75.000000  70.300003  70.800003    ...     16.780001  17.620001
# ...

# %%
#setting the columns name
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
#checking the head
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                                    CG  \
# Stock Info    Open   High    Low  Close  Adj Close     Volume       Open
# Date
# 2008-12-31   13.09  14.12  13.00  14.08  12.812518  113351000  67.199997
# 2009-01-02   13.92  14.57  13.71  14.33  13.040014   86580700  68.699997
# 2009-01-05   14.38  14.55  13.89  13.98  12.721521   93640500  71.199997
# 2009-01-06   14.27  14.81  14.07  14.28  12.994514  111015400  72.900002
# 2009-01-07   14.11  14.13  13.61  13.71  12.475824  112810000  72.199997
#
# Bank Ticker                                     ...            MS             \
# Stock Info        High        Low      Close    ...           Low      Close
# Date                                            ...
# 2008-12-31   70.400002  66.199997  67.099998    ...     15.030000  16.040001
# 2009-01-02   71.599998  67.500000  71.400002    ...     15.750000  16.990000
# 2009-01-05   75.000000  70.300003  70.800003    ...     16.780001  17.620001
# ...

# %%
#checking the max Closing price for each bank's stock
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     32.840000
# CG      80.080002
# GS     273.380005
# JPM    118.769997
# MS      58.910000
# WFC     65.930000
# dtype: float64

# %% [markdown]
# ** Creating a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns will be typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$
